# %%
# TODO:
# Calcular bien cuándo empieza la medida de QoE
# Revisar Cuando empieza la entrada de los usuarios en el media server
# Revisar el tiempo que tarda en meterse X usuarios en el media server
# Revisar manualmente los videos
# Mediaserver con mejor rendimiento
# Estimar costes de tests para mediasoup
# Separar métricas audio de video
# Elegir una medida de video (o media o VMAF o algo) -> VMAF por el paper de Boni
# Elegir una medida de audio (o media o VISQOL o PESQ o buscar en literatura o algo) -> VISQOL por el paper de Google
# Análisis con medidas QoS
# Medir streams que están en el media server (entrada y salida)
# ¿Cómo afecta el número de streams (entrada y salida) a las métricas QoE dado el mismo número de usuarios?
# ¿Cómo afecta la topología a las métricas dado el mismo número de usuarios?
# ¿Cuándo/En base a qué valores de medidas cuantitativas podemos añadir más usuarios sin afectar a la calidad?


# Qué umbrales en los que QoS empieza a disminuir de manera importante en los media servers?

# RQs en orden

# TODO: acciones a realizar
# Decidir umbrales para: Calidad buena/moderada/mala
# De momento hacerlo a mano
# ¿Qué herramienta matemática nos ayuda a decidir esto?
# Aprendizaje automático, entrenando un modelo para que nos dé un umbral
# Ver cómo hacer el experimento para entranarlo (variables más importantes)

# Explicación/justificación de RQs: No se pueden utilizar las mismas métricas para QoS que en la web. Es relevante estudiar la relación entre medidas QoE y QoS.
# ¿Se pueden usar las mismas métricas utilizadas para escalar la web (CPU) que para la videoconferencia?

# Detalle del diseño experimental en vez de RQ: ¿Como varía la QoE en función del tamaño de máquina del cliente?
## SOLUCIÓN: Experimentación preliminar ya hecha

# RQ: ¿Es la CPU un buen predictor de la carga del sistema? (a lo mejor no queremos que sea una RQ)
## SOLUCIÓN: Principalmente en video, cuando la CPU entra en el rango 0.95 - 1 por primera vez, o cuando lleva unos 20-30 segundos en 1, en la mayoría de casos empeora un poco la calidad (se ve principalmente en los mínimos y máximos)
## SOLUCIÓN: Pero a partir de ahí no podemos saber qué pasa solo en base a la CPU
## TODO: Sacar umbrales númericos, pensar como sacar números primer momento en el que cpu está en 90%
## TODO: Todos los puntos entre 0% y 10, 10 y 20... 70 y 80%, todos entre 80% y 90%, todos entre 95% y 100% por primera vez
## TODO:

# RQ: ¿Es posible correlar las métricas de QoS para determinar un cambio en el QoE en cada experimento y en cada media server?
# Correlar los valores QoE (VMAF y VISQOL) con la escala MOS (1-5) por ej.: Calidad buena 5, calidad media 3, calidad mala 1
## SOLUCIÓN: Según sus propios algoritmos y tras nuestra normalización:
## Calidad excelente: Entre 1 y 0.8 (MOS 5)
## Calidad buena:     Entre 0.8 y 0.6 (MOS 4)
## Calidad media:     Entre 0.6 y 0.4 (MOS 3)
## Calidad pobre:     Entre 0.4 y 0.2 (MOS 2)
## Calidad mala:      Entre 0.2 y 0 (MOS 1)
## Problema: valores negativos en VISQOL -> tomarlos como 0? Punto débil en cómo se analiza la calidad de audio
# TODO: Revisar datos audio DONE
# TODO: Revisar videos DONE
# TODO: Rehacer pruebas mediasoup OV2 DONE
# TODO: Juntar las gráficas de kurento, lk y mediasaoup en 3 apiladas DONE
# TODO: Pensar si queremos deshacernos de MOS y tomar como tope 0.8

# Hacer gráfica en la que salen todas las métricas y determinar puntos de corte para calidad buena, media y mala

# RQ: ¿Hay alguna métrica de QoS que se pueda correlar con el QoE independientemente de la topología en cada media server?
# Mostrar número de streams en el media server y correlar con QoE
# Varias gráficas que lleguen al mismo punto, usando medidas relativas y normalizadas
# TODO: Regresiones entre medidas QoS y QoE

# RQ: ¿Se puede utilizar el mismo indicador de QoS para cualquier topología y cualquier media server?

# RQ: ¿Qué servidor de media es más eficiente? -> comparar número de usuarios con una determinada QoE
# RQ: Número de usuarios en N:N
# RQ: Número de usuarios en N:M


# ¿Todas las métricas correlan igual en todos los media servers?
# ¿Cómo afecta la topología a las métricas?


# Preguntas:
# ¿Qué medida cuantitativa podemos obtener para saber cuándo baja el QoE/QoS? (saber cuándo el server está lleno) (para determinar el punto de autoescalado)
# Límites de carga

# Gráfica que compare nº streams con CPU y QoE audio y video (una por experimento y otra que agregue todos los experimentos) para comparar LiveKit y Kurento

# Métricas y experimentos que nos gustaría saber por si repetimos la experimentación:
# - Métrica: Tiempo de conexión WebRTC (quitar tiempo de levantar browser, hacer peticiones...)
# - Experimento en el que se paren de meter usuarios en ciertos umbrales de CPU (parar en 80% y esperar, parar en 90% y esperar...)

# %% [markdown]
# kurento outbound data:
# - audio_bytesSent: Number of bytes sent for audio data
# - audio_packetsSent: Number of packets sent for audio data
# - audio_nackCount: Count the total number of Negative ACKnowledgement (NACK) packets, as defined in [RFC4585] section 6.2.1, received by this sender.
# - video_bytesSent: Number of bytes sent for video data
# - video_packetsSent: Number of packets sent for video data
# - video_framesEncoded: It represents the total number of frames successfully encoded for this RTP media stream.
# - video_nackCount: Number of negative acknowledgment packets sent for video data
# - video_firCount: Count the total number of Full Intra Request (FIR) packets, as defined in [RFC5104] section 4.3.1, received by this sender.
# - video_pliCount: Count the total number of Picture Loss Indication (PLI) packets, as defined in [RFC4585] section 6.3.1, received by this sender
# - video_qpSum: The sum of the QP values of frames encoded by this sender. The count of frames is in framesEncoded.
#
# kurento inbound data:
# - audio_bytesReceived: Number of bytes received for audio data
# - audio_packetsReceived: Number of packets received for audio data
# - audio_packetsLost: Number of packets lost for audio data
# - audio_jitter: Jitter value for audio data
# - video_bytesReceived: Number of bytes received for video data
# - video_packetsReceived: Number of packets received for video data
# - video_packetsLost: Number of packets lost for video data
# - video_jitter: The Jitter measures the variation in packet delay
# - video_framesDecoded: Number of video frames decoded
# - video_nackCount: Count the total number of Negative ACKnowledgement (NACK) packets, as defined in [RFC4585] section 6.2.1, sent by this receiver.
# - video_firCount: Count the total number of Full Intra Request (FIR) packets, as defined in [RFC5104] section 4.3.1, sent by this receiver
# - video_pliCount: Count the total number of Picture Loss Indication (PLI) packets, as defined in [RFC4585] section 6.3.1, sent by this receiver.
#
# livekit outbound data:
# - audio_packetsSent: Number of packets sent for audio data
# - audio_bytesSent: Number of bytes sent for audio data
# - audio_nackCount: Number of negative acknowledgment packets sent for audio data
#
# livekit inbound data:
# - audio_bytesReceived: Number of bytes received for audio data
# - audio_concealedSamples: Number of concealed samples for audio data
# - audio_jitter: Jitter value for audio data
# - audio_silentConcealedSamples: Number of silent concealed samples for audio data
# - audio_totalAudioEnergy: Total audio energy for audio data
# - audio_totalSamplesDuration: Total duration of audio samples for audio data
# - audio_fecPacketsDiscarded: Number of Forward Error Correction (FEC) packets discarded for audio data
# - audio_fecPacketsReceived: Number of Forward Error Correction (FEC) packets received for audio data
# - audio_insertedSamplesForDeceleration: Number of inserted samples for deceleration for audio data
# - audio_jitterBufferDelay: Jitter buffer delay for audio data
# - audio_jitterBufferEmittedCount: Number of samples emitted from the jitter buffer for audio data
# - audio_lastPacketReceivedTimestamp: Timestamp of the last received packet for audio data
# - audio_packetsDiscarded: Number of packets discarded for audio data
# - audio_packetsLost: Number of packets lost for audio data
# - audio_packetsReceived: Number of packets received for audio data
# - audio_removedSamplesForAcceleration: Number of removed samples for acceleration for audio data
# - audio_ssrc: Synchronization Source (SSRC) identifier for audio data
# - audio_totalSamplesReceived: Total number of samples received for audio data
# - video_bytesReceived: Number of bytes received for video data
# - video_firCount: Number of Full Intra Request (FIR) packets received for video data
# - video_frameHeight: Height of video frames for video data
# - video_frameWidth: Width of video frames for video data
# - video_framesDecoded: Number of video frames decoded
# - video_framesDropped: Number of video frames dropped
# - video_framesReceived: Number of video frames received
# - video_jitter: Jitter value for video data
# - video_nackCount: Number of negative acknowledgment packets received for video data
# - video_packetsLost: Number of packets lost for video data
# - video_packetsReceived: Number of packets received for video data
# - video_pliCount: Number of Picture Loss Indication (PLI) packets received for video data
# - video_timestamp: Timestamp of video data
# - video_type: Type of video data
# - video_ssrc: Synchronization Source (SSRC) identifier for video data
# - video_discardedPackets: Number of discarded packets for video data
# - video_packetsDiscarded: Number of packets discarded for video data
# - video_framesPerSecond: Number of video frames per second
# - video_jitterBufferDelay: Jitter buffer delay for video data
# - video_jitterBufferEmittedCount: Number of samples emitted from the jitter buffer for video data
# - video_totalDecodeTime: Total decode time for video data
# - video_totalInterFrameDelay: Total inter-frame delay for video data
# - video_totalProcessingDelay: Total processing delay for video data
# - video_totalSquaredInterFrameDelay: Total squared inter-frame delay for video data
